# %% [markdown]
# <a href="https://colab.research.google.com/github/AbhiramBalakrishnaBhat/python-basics/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
supermarket=files.upload()
# Out:
#      <input type="file" id="files-30628594-2d86-466e-b603-75e78d2c3339" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-30628594-2d86-466e-b603-75e78d2c3339">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
teams_and_leagues=files.upload()
# Out:
#      <input type="file" id="files-56c68789-e8d3-49b7-9962-4da6c7d4b1e2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-56c68789-e8d3-49b7-9962-4da6c7d4b1e2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
teamgoals=pd.DataFrame({'teams':['spain','england'],'goals':[2,4]})
print(teamgoals)
# Out:
#      teams  goals
# 0    spain      2
# 1  england      4

# %%
import pandas as pd
match1=pd.DataFrame({'players':['messi','ronaldo'],'country':['argentina','portugal']})
print(match1)
# Out:
#    players    country
# 0    messi  argentina
# 1  ronaldo   portugal

# %%
import pandas as pd
sub=['hindi','english','fa']
marks=pd.DataFrame(sub)
print(marks)
# Out:
#          0
# 0    hindi
# 1  english
# 2       fa

# %%
import pandas as pd
dataframe=pd.read_csv('Supermarket_sales.csv')
#print(dataframe)
print("*****")
print(dataframe.head(5))
print(dataframe['City'])
print(dataframe[['Branch','Customertype']])

for i in dataframe.index:
  print(dataframe.City[i],dataframe.Branch[i])
# Out:
# *****
#    No    InvoiceID Branch       City Customertype  Gender  \
# 0   1  750-67-8428      A     Yangon       Member  Female
# 1   2  226-31-3081      C  Naypyitaw       Normal  Female
# 2   3  631-41-3108      A     Yangon       Normal    Male
# 3   4  123-19-1176      A     Yangon       Member    Male
# 4   5  373-73-7910      A     Yangon       Normal    Male
#
#               Productline  Unitprice  Quantity      Tax     Total       Date  \
# 0       Health and beauty      74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories      15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle      46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty      58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel      86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross_margin_percentage  gross_iincome  Rating
# ...

# %%
from google.colab import files
players=files.upload()
# Out:
#      <input type="file" id="files-d8682394-46c7-4895-a6e7-ac3d8763d4f2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d8682394-46c7-4895-a6e7-ac3d8763d4f2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df2=pd.read_csv('players_20.csv')
max=df2.overall.max()
max2=df2.age.max()
#max1=df2.overall.idxmax()
#per=df2.loc[max_overall_loc]
#print(person.long_name,'has the highest overall of',max_overall)
print(max2)
# Out:
# 42
