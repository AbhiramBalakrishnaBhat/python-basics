# %% [markdown]
# <a href="https://colab.research.google.com/github/AbhiramBalakrishnaBhat/python-basics/blob/main/Untitled16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
file=files.upload()
# Out:
#      <input type="file" id="files-df4cd03a-9203-41f1-8a83-bee5c63e34e4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-df4cd03a-9203-41f1-8a83-bee5c63e34e4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df= pd.read_csv("SOCR-HeightWeight.csv")
import matplotlib.pyplot as plt
import plotly.express as px
height=df['Height(Inches)']
weight=df['Weight(Pounds)']
print("Mean Height of the class: ",height.mean())
print("Mean WEeight of the class: ",weight.mean())
print("Median Height of the class: ",height.median())
print("Median Weight of the class: ",weight.median())
print("Mode Height of the class: ",height.mode())
print("Mode Weight of the class: ",weight.mode())
plt.scatter(height,weight,color='r')
plt.show()
#plt.scatter(height,weight) 
#figure=px.scatter(height,weight)
#figure.show()
# Out:
# Mean Height of the class:  67.99311359679999
# Mean WEeight of the class:  127.07942116080001
# Median Height of the class:  67.9957
# Median Weight of the class:  127.15775
# Mode Height of the class:  0     65.65796
# 1     67.34629
# 2     67.41672
# 3     67.94061
# 4     67.97769
# 5     67.98509
# 6     68.30287
# 7     68.92380
# 8     68.93456
# 9     68.97830
# 10    70.04724
# dtype: float64
# Mode Weight of the class:  0    124.7975
# dtype: float64

# %%
from google.colab import files
linefile=files.upload()
# Out:
#      <input type="file" id="files-d02fef43-5536-47dd-bc84-bb4d85d8f890" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d02fef43-5536-47dd-bc84-bb4d85d8f890">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df= pd.read_csv("line_chart.csv")
print(df.head(4))
year=df['Year']
yvalues=df['Per capita income']
zvalues=df['Country']
figure=plt.plot(year,yvalues)
plt.show()
# Out:
#   Country  Year  Per capita income
# 0   Aruba  2002       20436.887129
# 1   Aruba  2003       20833.761612
# 2   Aruba  2004       22569.974985
# 3   Aruba  2005       23300.039558
